# %% [markdown]
# <a href="https://colab.research.google.com/github/prahladpunia/AI/blob/main/TD3_Half_Humanoid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Twin-Delayed DDPG

# %% [markdown]
# ## Installing the packages

# %%
# !pip install pybullet
# Out:
# Collecting pybullet
#   Downloading pybullet-3.2.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (90.8 MB)
#      |████████████████████████████████| 90.8 MB 1.2 MB/s
# Installing collected packages: pybullet
# Successfully installed pybullet-3.2.1

# %% [markdown]
# ## Importing the libraries

# %%
import os
import time
import random
import numpy as np
import matplotlib.pyplot as plt
import pybullet_envs
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
from gym import wrappers
from torch.autograd import Variable
from collections import deque

# %% [markdown]
# ## Step 1: We initialize the Experience Replay memory

# %%
class ReplayBuffer(object):

  def __init__(self, max_size=1e6):
    self.storage = []
    self.max_size = max_size
    self.ptr = 0

  def add(self, transition):
    if len(self.storage) == self.max_size:
      self.storage[int(self.ptr)] = transition
      self.ptr = (self.ptr + 1) % self.max_size
    else:
      self.storage.append(transition)

  def sample(self, batch_size):
    ind = np.random.randint(0, len(self.storage), size=batch_size)
    batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = [], [], [], [], []
    for i in ind: 
      state, next_state, action, reward, done = self.storage[i]
      batch_states.append(np.array(state, copy=False))
      batch_next_states.append(np.array(next_state, copy=False))
      batch_actions.append(np.array(action, copy=False))
      batch_rewards.append(np.array(reward, copy=False))
      batch_dones.append(np.array(done, copy=False))
    return np.array(batch_states), np.array(batch_next_states), np.array(batch_actions), np.array(batch_rewards).reshape(-1, 1), np.array(batch_dones).reshape(-1, 1)

# %% [markdown]
# ## Step 2: We build one neural network for the Actor model and one neural network for the Actor target

# %%
class Actor(nn.Module):
  
  def __init__(self, state_dim, action_dim, max_action):
    super(Actor, self).__init__()
    self.layer_1 = nn.Linear(state_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, action_dim)
    self.max_action = max_action

  def forward(self, x):
    x = F.relu(self.layer_1(x))
    x = F.relu(self.layer_2(x))
    x = self.max_action * torch.tanh(self.layer_3(x))
    return x

# %% [markdown]
# ## Step 3: We build two neural networks for the two Critic models and two neural networks for the two Critic targets

# %%
class Critic(nn.Module):
  
  def __init__(self, state_dim, action_dim):
    super(Critic, self).__init__()
    # Defining the first Critic neural network
    self.layer_1 = nn.Linear(state_dim + action_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, 1)
    # Defining the second Critic neural network
    self.layer_4 = nn.Linear(state_dim + action_dim, 400)
    self.layer_5 = nn.Linear(400, 300)
    self.layer_6 = nn.Linear(300, 1)

  def forward(self, x, u):
    xu = torch.cat([x, u], 1)
    # Forward-Propagation on the first Critic Neural Network
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    # Forward-Propagation on the second Critic Neural Network
    x2 = F.relu(self.layer_4(xu))
    x2 = F.relu(self.layer_5(x2))
    x2 = self.layer_6(x2)
    return x1, x2

  def Q1(self, x, u):
    xu = torch.cat([x, u], 1)
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    return x1

# %% [markdown]
# ## Steps 4 to 15: Training Process

# %%
# Selecting the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Building the whole Training Process into a class

class TD3(object):
  
  def __init__(self, state_dim, action_dim, max_action):
    self.actor = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target.load_state_dict(self.actor.state_dict())
    self.actor_optimizer = torch.optim.Adam(self.actor.parameters())
    self.critic = Critic(state_dim, action_dim).to(device)
    self.critic_target = Critic(state_dim, action_dim).to(device)
    self.critic_target.load_state_dict(self.critic.state_dict())
    self.critic_optimizer = torch.optim.Adam(self.critic.parameters())
    self.max_action = max_action

  def select_action(self, state):
    state = torch.Tensor(state.reshape(1, -1)).to(device)
    return self.actor(state).cpu().data.numpy().flatten()

  def train(self, replay_buffer, iterations, batch_size=100, discount=0.99, tau=0.005, policy_noise=0.2, noise_clip=0.5, policy_freq=2):
    
    for it in range(iterations):
      
      # Step 4: We sample a batch of transitions (s, s’, a, r) from the memory
      batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = replay_buffer.sample(batch_size)
      state = torch.Tensor(batch_states).to(device)
      next_state = torch.Tensor(batch_next_states).to(device)
      action = torch.Tensor(batch_actions).to(device)
      reward = torch.Tensor(batch_rewards).to(device)
      done = torch.Tensor(batch_dones).to(device)
      
      # Step 5: From the next state s’, the Actor target plays the next action a’
      next_action = self.actor_target(next_state)
      
      # Step 6: We add Gaussian noise to this next action a’ and we clamp it in a range of values supported by the environment
      noise = torch.Tensor(batch_actions).data.normal_(0, policy_noise).to(device)
      noise = noise.clamp(-noise_clip, noise_clip)
      next_action = (next_action + noise).clamp(-self.max_action, self.max_action)
      
      # Step 7: The two Critic targets take each the couple (s’, a’) as input and return two Q-values Qt1(s’,a’) and Qt2(s’,a’) as outputs
      target_Q1, target_Q2 = self.critic_target(next_state, next_action)
      
      # Step 8: We keep the minimum of these two Q-values: min(Qt1, Qt2)
      target_Q = torch.min(target_Q1, target_Q2)
      
      # Step 9: We get the final target of the two Critic models, which is: Qt = r + γ * min(Qt1, Qt2), where γ is the discount factor
      target_Q = reward + ((1 - done) * discount * target_Q).detach()
      
      # Step 10: The two Critic models take each the couple (s, a) as input and return two Q-values Q1(s,a) and Q2(s,a) as outputs
      current_Q1, current_Q2 = self.critic(state, action)
      
      # Step 11: We compute the loss coming from the two Critic models: Critic Loss = MSE_Loss(Q1(s,a), Qt) + MSE_Loss(Q2(s,a), Qt)
      critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)
      
      # Step 12: We backpropagate this Critic loss and update the parameters of the two Critic models with a SGD optimizer
      self.critic_optimizer.zero_grad()
      critic_loss.backward()
      self.critic_optimizer.step()
      
      # Step 13: Once every two iterations, we update our Actor model by performing gradient ascent on the output of the first Critic model
      if it % policy_freq == 0:
        actor_loss = -self.critic.Q1(state, self.actor(state)).mean()
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()
        
        # Step 14: Still once every two iterations, we update the weights of the Actor target by polyak averaging
        for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
        
        # Step 15: Still once every two iterations, we update the weights of the Critic target by polyak averaging
        for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
  
  # Making a save method to save a trained model
  def save(self, filename, directory):
    torch.save(self.actor.state_dict(), '%s/%s_actor.pth' % (directory, filename))
    torch.save(self.critic.state_dict(), '%s/%s_critic.pth' % (directory, filename))
  
  # Making a load method to load a pre-trained model
  def load(self, filename, directory):
    self.actor.load_state_dict(torch.load('%s/%s_actor.pth' % (directory, filename)))
    self.critic.load_state_dict(torch.load('%s/%s_critic.pth' % (directory, filename)))

# %% [markdown]
# ## We make a function that evaluates the policy by calculating its average reward over 10 episodes

# %%
def evaluate_policy(policy, eval_episodes=10):
  avg_reward = 0.
  for _ in range(eval_episodes):
    obs = env.reset()
    done = False
    while not done:
      action = policy.select_action(np.array(obs))
      obs, reward, done, _ = env.step(action)
      avg_reward += reward
  avg_reward /= eval_episodes
  print ("---------------------------------------")
  print ("Average Reward over the Evaluation Step: %f" % (avg_reward))
  print ("---------------------------------------")
  return avg_reward

# %% [markdown]
# ## We set the parameters

# %%
env_name = "Walker2DBulletEnv-v0" # Name of a environment (set it to any Continous environment you want)
seed = 0 # Random seed number
start_timesteps = 1e4 # Number of iterations/timesteps before which the model randomly chooses an action, and after which it starts to use the policy network
eval_freq = 5e3 # How often the evaluation step is performed (after how many timesteps)
max_timesteps = 10e5 # Total number of iterations/timesteps
save_models = True # Boolean checker whether or not to save the pre-trained model
expl_noise = 0.1 # Exploration noise - STD value of exploration Gaussian noise
batch_size = 100 # Size of the batch
discount = 0.99 # Discount factor gamma, used in the calculation of the total discounted reward
tau = 0.005 # Target network update rate
policy_noise = 0.2 # STD of Gaussian noise added to the actions for the exploration purposes
noise_clip = 0.5 # Maximum value of the Gaussian noise added to the actions (policy)
policy_freq = 2 # Number of iterations to wait before the policy network (Actor model) is updated

# %% [markdown]
# ## We create a file name for the two saved models: the Actor and Critic models

# %%
file_name = "%s_%s_%s" % ("TD3", env_name, str(seed))
print ("---------------------------------------")
print ("Settings: %s" % (file_name))
print ("---------------------------------------")
# Out:
# ---------------------------------------
# Settings: TD3_Walker2DBulletEnv-v0_0
# ---------------------------------------

# %% [markdown]
# ## We create a folder inside which will be saved the trained models

# %%
if not os.path.exists("./results"):
  os.makedirs("./results")
if save_models and not os.path.exists("./pytorch_models"):
  os.makedirs("./pytorch_models")

# %% [markdown]
# ## We create the PyBullet environment

# %%
env = gym.make(env_name)

# %% [markdown]
# ## We set seeds and we get the necessary information on the states and actions in the chosen environment

# %%
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

# %% [markdown]
# ## We create the policy network (the Actor model)

# %%
policy = TD3(state_dim, action_dim, max_action)

# %% [markdown]
# ## We create the Experience Replay memory

# %%
replay_buffer = ReplayBuffer()

# %% [markdown]
# ## We define a list where all the evaluation results over 10 episodes are stored

# %%
evaluations = [evaluate_policy(policy)]
# Out:
# ---------------------------------------
# Average Reward over the Evaluation Step: 264.967242
# ---------------------------------------

# %% [markdown]
# ## We create a new folder directory in which the final results (videos of the agent) will be populated

# %%
def mkdir(base, name):
    path = os.path.join(base, name)
    if not os.path.exists(path):
        os.makedirs(path)
    return path
work_dir = mkdir('exp', 'brs')
monitor_dir = mkdir(work_dir, 'monitor')
max_episode_steps = env._max_episode_steps
save_env_vid = False
if save_env_vid:
  env = wrappers.Monitor(env, monitor_dir, force = True)
  env.reset()

# %% [markdown]
# ## We initialize the variables

# %%
total_timesteps = 0
timesteps_since_eval = 0
episode_num = 0
done = True
t0 = time.time()

# %% [markdown]
# ## Training

# %%
# We start the main loop over 500,000 timesteps
while total_timesteps < max_timesteps:
  
  # If the episode is done
  if done:

    # If we are not at the very beginning, we start the training process of the model
    if total_timesteps != 0:
      print("Total Timesteps: {} Episode Num: {} Reward: {}".format(total_timesteps, episode_num, episode_reward))
      policy.train(replay_buffer, episode_timesteps, batch_size, discount, tau, policy_noise, noise_clip, policy_freq)

    # We evaluate the episode and we save the policy
    if timesteps_since_eval >= eval_freq:
      timesteps_since_eval %= eval_freq
      evaluations.append(evaluate_policy(policy))
      policy.save(file_name, directory="./pytorch_models")
      np.save("./results/%s" % (file_name), evaluations)
    
    # When the training step is done, we reset the state of the environment
    obs = env.reset()
    
    # Set the Done to False
    done = False
    
    # Set rewards and episode timesteps to zero
    episode_reward = 0
    episode_timesteps = 0
    episode_num += 1
  
  # Before 10000 timesteps, we play random actions
  if total_timesteps < start_timesteps:
    action = env.action_space.sample()
  else: # After 10000 timesteps, we switch to the model
    action = policy.select_action(np.array(obs))
    # If the explore_noise parameter is not 0, we add noise to the action and we clip it
    if expl_noise != 0:
      action = (action + np.random.normal(0, expl_noise, size=env.action_space.shape[0])).clip(env.action_space.low, env.action_space.high)
  
  # The agent performs the action in the environment, then reaches the next state and receives the reward
  new_obs, reward, done, _ = env.step(action)
  
  # We check if the episode is done
  done_bool = 0 if episode_timesteps + 1 == env._max_episode_steps else float(done)
  
  # We increase the total reward
  episode_reward += reward
  
  # We store the new transition into the Experience Replay memory (ReplayBuffer)
  replay_buffer.add((obs, new_obs, action, reward, done_bool))

  # We update the state, the episode timestep, the total timesteps, and the timesteps since the evaluation of the policy
  obs = new_obs
  episode_timesteps += 1
  total_timesteps += 1
  timesteps_since_eval += 1

# We add the last policy evaluation to our list of evaluations and we save our model
evaluations.append(evaluate_policy(policy))
if save_models: policy.save("%s" % (file_name), directory="./pytorch_models")
np.save("./results/%s" % (file_name), evaluations)
# Out:
# Total Timesteps: 9 Episode Num: 1 Reward: 13.028725326954739
# Total Timesteps: 19 Episode Num: 2 Reward: 13.964895089941274
# Total Timesteps: 32 Episode Num: 3 Reward: 16.043313741970632
# Total Timesteps: 43 Episode Num: 4 Reward: 15.047632216785859
# Total Timesteps: 53 Episode Num: 5 Reward: 13.348051702804513
# Total Timesteps: 66 Episode Num: 6 Reward: 16.776778883839143
# Total Timesteps: 85 Episode Num: 7 Reward: 19.501350387588896
# Total Timesteps: 105 Episode Num: 8 Reward: 21.609382811827526
# Total Timesteps: 121 Episode Num: 9 Reward: 15.922838647384195
# Total Timesteps: 130 Episode Num: 10 Reward: 12.995662065120996
# Total Timesteps: 140 Episode Num: 11 Reward: 14.920030439097898
# Total Timesteps: 163 Episode Num: 12 Reward: 23.15714511029946
# Total Timesteps: 179 Episode Num: 13 Reward: 16.934112591107258
# Total Timesteps: 188 Episode Num: 14 Reward: 13.970096583446137
# Total Timesteps: 199 Episode Num: 15 Reward: 14.813412954080558
# Total Timesteps: 216 Episode Num: 16 Reward: 21.454057900252522
# Total Timesteps: 235 Episode Num: 17 Reward: 20.094598211499395
# Total Timesteps: 252 Episode Num: 18 Reward: 19.184379379395974
# Total Timesteps: 264 Episode Num: 19 Reward: 15.360196617088514
# Total Timesteps: 297 Episode Num: 20 Reward: 23.737003660613844
# Total Timesteps: 307 Episode Num: 21 Reward: 14.378549910380388
# Total Timesteps: 316 Episode Num: 22 Reward: 11.414869261901185
# Total Timesteps: 327 Episode Num: 23 Reward: 15.76065809984575
# Total Timesteps: 342 Episode Num: 24 Reward: 15.673692237063369
# Total Timesteps: 353 Episode Num: 25 Reward: 16.050052046639028
# Total Timesteps: 369 Episode Num: 26 Reward: 16.868149481443105
# Total Timesteps: 381 Episode Num: 27 Reward: 14.92437078796793
# Total Timesteps: 401 Episode Num: 28 Reward: 19.052458263735755
# Total Timesteps: 410 Episode Num: 29 Reward: 12.510010241852434
# Total Timesteps: 418 Episode Num: 30 Reward: 14.436511400190648
# Total Timesteps: 429 Episode Num: 31 Reward: 13.5243593125997
# Total Timesteps: 446 Episode Num: 32 Reward: 19.192827379093792
# Total Timesteps: 455 Episode Num: 33 Reward: 13.841859632154229
# Total Timesteps: 467 Episode Num: 34 Reward: 16.641906416563142
# Total Timesteps: 476 Episode Num: 35 Reward: 14.835715196689126
# Total Timesteps: 485 Episode Num: 36 Reward: 13.947299227739858
# Total Timesteps: 493 Episode Num: 37 Reward: 13.1999851294182
# Total Timesteps: 503 Episode Num: 38 Reward: 14.705511913432565
# Total Timesteps: 511 Episode Num: 39 Reward: 12.316568622959313
# Total Timesteps: 528 Episode Num: 40 Reward: 18.542924602520365
# Total Timesteps: 555 Episode Num: 41 Reward: 23.07946683640329
# Total Timesteps: 576 Episode Num: 42 Reward: 20.857795562333195
# Total Timesteps: 604 Episode Num: 43 Reward: 18.877785925711215
# Total Timesteps: 623 Episode Num: 44 Reward: 19.721034661732848
# Total Timesteps: 638 Episode Num: 45 Reward: 17.634666870844374
# Total Timesteps: 658 Episode Num: 46 Reward: 18.434495902823983
# Total Timesteps: 669 Episode Num: 47 Reward: 13.149623366295419
# Total Timesteps: 688 Episode Num: 48 Reward: 20.611294531915334
# Total Timesteps: 699 Episode Num: 49 Reward: 15.801122656778897
# Total Timesteps: 708 Episode Num: 50 Reward: 13.15107386767049
# Total Timesteps: 718 Episode Num: 51 Reward: 13.975977401896671
# Total Timesteps: 726 Episode Num: 52 Reward: 13.495611648673366
# Total Timesteps: 742 Episode Num: 53 Reward: 19.947766221739585
# Total Timesteps: 749 Episode Num: 54 Reward: 13.006283849343891
# Total Timesteps: 778 Episode Num: 55 Reward: 24.15299986970786
# Total Timesteps: 794 Episode Num: 56 Reward: 18.425001962922398
# Total Timesteps: 811 Episode Num: 57 Reward: 17.7149223491142
# Total Timesteps: 825 Episode Num: 58 Reward: 13.360063404658288
# Total Timesteps: 850 Episode Num: 59 Reward: 22.551077959116085
# Total Timesteps: 857 Episode Num: 60 Reward: 12.241022587189219
# Total Timesteps: 881 Episode Num: 61 Reward: 22.85955665190995
# Total Timesteps: 891 Episode Num: 62 Reward: 15.179241668879692
# Total Timesteps: 899 Episode Num: 63 Reward: 12.810299209100778
# Total Timesteps: 911 Episode Num: 64 Reward: 14.64616099345294
# Total Timesteps: 919 Episode Num: 65 Reward: 12.02583571174473
# Total Timesteps: 930 Episode Num: 66 Reward: 15.807324355802848
# Total Timesteps: 938 Episode Num: 67 Reward: 12.291208991641179
# Total Timesteps: 956 Episode Num: 68 Reward: 21.148531351907874
# Total Timesteps: 964 Episode Num: 69 Reward: 13.692118375991413
# Total Timesteps: 972 Episode Num: 70 Reward: 13.580030240908673
# Total Timesteps: 983 Episode Num: 71 Reward: 14.956224395944446
# Total Timesteps: 996 Episode Num: 72 Reward: 17.48034733898239
# Total Timesteps: 1008 Episode Num: 73 Reward: 16.049988098719044
# Total Timesteps: 1029 Episode Num: 74 Reward: 20.281073942413784
# Total Timesteps: 1051 Episode Num: 75 Reward: 22.297367128092453
# Total Timesteps: 1072 Episode Num: 76 Reward: 21.258484355603287
# Total Timesteps: 1082 Episode Num: 77 Reward: 14.862083739256194
# Total Timesteps: 1093 Episode Num: 78 Reward: 16.71211550809385
# Total Timesteps: 1104 Episode Num: 79 Reward: 14.67260002709372
# Total Timesteps: 1129 Episode Num: 80 Reward: 26.70454110630526
# Total Timesteps: 1148 Episode Num: 81 Reward: 20.491507919607102
# Total Timesteps: 1160 Episode Num: 82 Reward: 14.965876281920647
# Total Timesteps: 1184 Episode Num: 83 Reward: 19.333396988014282
# Total Timesteps: 1203 Episode Num: 84 Reward: 17.192564326827412
# Total Timesteps: 1215 Episode Num: 85 Reward: 16.57914657583169
# Total Timesteps: 1228 Episode Num: 86 Reward: 16.128364545904333
# Total Timesteps: 1244 Episode Num: 87 Reward: 14.096767111192452
# Total Timesteps: 1258 Episode Num: 88 Reward: 16.62296425882523
# Total Timesteps: 1267 Episode Num: 89 Reward: 13.377749543955725
# Total Timesteps: 1281 Episode Num: 90 Reward: 16.702419299188477
# Total Timesteps: 1289 Episode Num: 91 Reward: 12.80874009262625
# Total Timesteps: 1300 Episode Num: 92 Reward: 15.930353799689325
# Total Timesteps: 1311 Episode Num: 93 Reward: 16.07492692814121
# Total Timesteps: 1323 Episode Num: 94 Reward: 17.53973007453169
# Total Timesteps: 1347 Episode Num: 95 Reward: 23.26327409832593
# Total Timesteps: 1365 Episode Num: 96 Reward: 19.545853197574615
# Total Timesteps: 1377 Episode Num: 97 Reward: 14.971349987910072
# Total Timesteps: 1387 Episode Num: 98 Reward: 14.22836332625011
# Total Timesteps: 1399 Episode Num: 99 Reward: 15.38240161406429
# Total Timesteps: 1414 Episode Num: 100 Reward: 16.728330962649483
# Total Timesteps: 1427 Episode Num: 101 Reward: 16.028734647370584
# Total Timesteps: 1443 Episode Num: 102 Reward: 17.988901836914007
# Total Timesteps: 1450 Episode Num: 103 Reward: 11.753125158439797
# Total Timesteps: 1460 Episode Num: 104 Reward: 14.414396723522806
# Total Timesteps: 1475 Episode Num: 105 Reward: 17.01499986457202
# Total Timesteps: 1499 Episode Num: 106 Reward: 22.004834090685474
# Total Timesteps: 1511 Episode Num: 107 Reward: 13.352866440228537
# Total Timesteps: 1519 Episode Num: 108 Reward: 12.052038502533104
# Total Timesteps: 1529 Episode Num: 109 Reward: 14.334280226279224
# Total Timesteps: 1540 Episode Num: 110 Reward: 14.67977864046552
# Total Timesteps: 1557 Episode Num: 111 Reward: 20.904659456043735
# Total Timesteps: 1574 Episode Num: 112 Reward: 17.805638181506946
# Total Timesteps: 1586 Episode Num: 113 Reward: 14.00116384873836
# Total Timesteps: 1603 Episode Num: 114 Reward: 18.27013625474356
# Total Timesteps: 1614 Episode Num: 115 Reward: 14.44424846766633
# Total Timesteps: 1634 Episode Num: 116 Reward: 19.950847546290607
# Total Timesteps: 1645 Episode Num: 117 Reward: 14.028667388157919
# Total Timesteps: 1659 Episode Num: 118 Reward: 16.272191405114427
# Total Timesteps: 1674 Episode Num: 119 Reward: 17.198328088504788
# Total Timesteps: 1683 Episode Num: 120 Reward: 14.783101831169915
# Total Timesteps: 1698 Episode Num: 121 Reward: 15.947058183206536
# Total Timesteps: 1705 Episode Num: 122 Reward: 10.488430649950168
# Total Timesteps: 1724 Episode Num: 123 Reward: 20.579033822160277
# Total Timesteps: 1736 Episode Num: 124 Reward: 15.425490708532742
# Total Timesteps: 1744 Episode Num: 125 Reward: 12.857588576327544
# Total Timesteps: 1757 Episode Num: 126 Reward: 16.541306922771035
# Total Timesteps: 1769 Episode Num: 127 Reward: 15.607128110394115
# Total Timesteps: 1779 Episode Num: 128 Reward: 14.583165811370417
# Total Timesteps: 1787 Episode Num: 129 Reward: 12.980844453678582
# Total Timesteps: 1796 Episode Num: 130 Reward: 12.981072652651346
# Total Timesteps: 1816 Episode Num: 131 Reward: 20.58866132948751
# Total Timesteps: 1826 Episode Num: 132 Reward: 15.60344956619665
# Total Timesteps: 1839 Episode Num: 133 Reward: 15.899842769131645
# Total Timesteps: 1852 Episode Num: 134 Reward: 16.00595078792685
# Total Timesteps: 1867 Episode Num: 135 Reward: 19.10426575282472
# Total Timesteps: 1878 Episode Num: 136 Reward: 14.512380934917017
# Total Timesteps: 1886 Episode Num: 137 Reward: 11.901786718664516
# Total Timesteps: 1915 Episode Num: 138 Reward: 29.386025339117623
# Total Timesteps: 1932 Episode Num: 139 Reward: 18.939304496950353
# Total Timesteps: 1947 Episode Num: 140 Reward: 18.064885370551202
# Total Timesteps: 1963 Episode Num: 141 Reward: 18.150500221909898
# Total Timesteps: 1980 Episode Num: 142 Reward: 16.91181794540898
# Total Timesteps: 2000 Episode Num: 143 Reward: 21.306353051913902
# Total Timesteps: 2015 Episode Num: 144 Reward: 18.392924584422143
# Total Timesteps: 2027 Episode Num: 145 Reward: 14.882101415557553
# Total Timesteps: 2051 Episode Num: 146 Reward: 20.060249702383587
# Total Timesteps: 2072 Episode Num: 147 Reward: 21.318597445737396
# Total Timesteps: 2083 Episode Num: 148 Reward: 13.831176717343624
# Total Timesteps: 2111 Episode Num: 149 Reward: 18.753509836297596
# Total Timesteps: 2127 Episode Num: 150 Reward: 18.54412175752077
# Total Timesteps: 2138 Episode Num: 151 Reward: 15.285353999126524
# Total Timesteps: 2160 Episode Num: 152 Reward: 20.522334573330593
# Total Timesteps: 2169 Episode Num: 153 Reward: 12.084466978478305
# Total Timesteps: 2187 Episode Num: 154 Reward: 19.91226377403509
# Total Timesteps: 2202 Episode Num: 155 Reward: 17.52707164993917
# Total Timesteps: 2214 Episode Num: 156 Reward: 15.1283316960762
# Total Timesteps: 2225 Episode Num: 157 Reward: 15.862737495361944
# Total Timesteps: 2243 Episode Num: 158 Reward: 17.629785886933675
# Total Timesteps: 2269 Episode Num: 159 Reward: 26.634581042631176
# Total Timesteps: 2289 Episode Num: 160 Reward: 21.951305956859144
# Total Timesteps: 2298 Episode Num: 161 Reward: 12.831086429007701
# Total Timesteps: 2315 Episode Num: 162 Reward: 17.777767311596836
# Total Timesteps: 2331 Episode Num: 163 Reward: 19.969674773278527
# Total Timesteps: 2339 Episode Num: 164 Reward: 13.679514416272285
# Total Timesteps: 2349 Episode Num: 165 Reward: 15.348020230158001
# Total Timesteps: 2367 Episode Num: 166 Reward: 18.688893314058074
# Total Timesteps: 2377 Episode Num: 167 Reward: 14.698977349826599
# Total Timesteps: 2394 Episode Num: 168 Reward: 19.69616728044348
# Total Timesteps: 2404 Episode Num: 169 Reward: 13.180655293377638
# Total Timesteps: 2416 Episode Num: 170 Reward: 14.230525744367332
# Total Timesteps: 2437 Episode Num: 171 Reward: 23.533506382035558
# Total Timesteps: 2456 Episode Num: 172 Reward: 18.721779329353012
# Total Timesteps: 2468 Episode Num: 173 Reward: 16.62605555082409
# Total Timesteps: 2476 Episode Num: 174 Reward: 13.032649583487364
# Total Timesteps: 2489 Episode Num: 175 Reward: 17.35275630679098
# Total Timesteps: 2507 Episode Num: 176 Reward: 18.661193574272325
# Total Timesteps: 2517 Episode Num: 177 Reward: 14.142731484871183
# Total Timesteps: 2526 Episode Num: 178 Reward: 13.924990417913069
# Total Timesteps: 2539 Episode Num: 179 Reward: 16.749926732004678
# Total Timesteps: 2557 Episode Num: 180 Reward: 19.269673760932346
# Total Timesteps: 2568 Episode Num: 181 Reward: 15.312350031372624
# Total Timesteps: 2576 Episode Num: 182 Reward: 14.285055386004386
# Total Timesteps: 2585 Episode Num: 183 Reward: 12.735974833030195
# Total Timesteps: 2595 Episode Num: 184 Reward: 15.791786159347975
# Total Timesteps: 2607 Episode Num: 185 Reward: 16.05272252018331
# Total Timesteps: 2614 Episode Num: 186 Reward: 11.85996759266418
# Total Timesteps: 2622 Episode Num: 187 Reward: 12.40690781603189
# Total Timesteps: 2646 Episode Num: 188 Reward: 20.705752891449084
# Total Timesteps: 2657 Episode Num: 189 Reward: 13.963101004081544
# Total Timesteps: 2674 Episode Num: 190 Reward: 16.68302768139838
# Total Timesteps: 2690 Episode Num: 191 Reward: 16.12092748325958
# Total Timesteps: 2701 Episode Num: 192 Reward: 15.936961108801189
# Total Timesteps: 2711 Episode Num: 193 Reward: 14.5975961210308
# Total Timesteps: 2724 Episode Num: 194 Reward: 17.232494303346904
# Total Timesteps: 2737 Episode Num: 195 Reward: 18.05591383488063
# Total Timesteps: 2750 Episode Num: 196 Reward: 15.621344129946372
# Total Timesteps: 2759 Episode Num: 197 Reward: 12.969527080154512
# Total Timesteps: 2777 Episode Num: 198 Reward: 17.728443036120737
# Total Timesteps: 2786 Episode Num: 199 Reward: 14.459525495917477
# Total Timesteps: 2806 Episode Num: 200 Reward: 19.47058989350771
# Total Timesteps: 2817 Episode Num: 201 Reward: 16.229585217050044
# Total Timesteps: 2826 Episode Num: 202 Reward: 14.316276710369857
# Total Timesteps: 2841 Episode Num: 203 Reward: 16.72828661224339
# Total Timesteps: 2861 Episode Num: 204 Reward: 19.57763865210727
# Total Timesteps: 2872 Episode Num: 205 Reward: 13.152208026277366
# Total Timesteps: 2879 Episode Num: 206 Reward: 11.800693894704455
# Total Timesteps: 2891 Episode Num: 207 Reward: 15.71808125073876
# Total Timesteps: 2908 Episode Num: 208 Reward: 18.267828534936417
# Total Timesteps: 2921 Episode Num: 209 Reward: 13.941907511581666
# Total Timesteps: 2929 Episode Num: 210 Reward: 12.251037571238703
# Total Timesteps: 2943 Episode Num: 211 Reward: 14.205539569961552
# Total Timesteps: 2951 Episode Num: 212 Reward: 12.937096365515025
# Total Timesteps: 2961 Episode Num: 213 Reward: 11.59757221497275
# Total Timesteps: 2980 Episode Num: 214 Reward: 20.730992034496737
# Total Timesteps: 2989 Episode Num: 215 Reward: 12.351857197715434
# Total Timesteps: 3011 Episode Num: 216 Reward: 20.07258237600181
# Total Timesteps: 853201 Episode Num: 2232 Reward: 1952.2748728978866
# Total Timesteps: 854201 Episode Num: 2233 Reward: 1806.664011555047
# Total Timesteps: 855201 Episode Num: 2234 Reward: 1819.6660406189392
# ---------------------------------------
# Average Reward over the Evaluation Step: 1982.387879
# ---------------------------------------
# Total Timesteps: 856201 Episode Num: 2235 Reward: 1964.1802029054002
# Total Timesteps: 857201 Episode Num: 2236 Reward: 1884.1383849405138
# Total Timesteps: 858201 Episode Num: 2237 Reward: 1918.5881833151138
# Total Timesteps: 859201 Episode Num: 2238 Reward: 1876.6557137370344
# Total Timesteps: 860201 Episode Num: 2239 Reward: 1817.521665843924
# ---------------------------------------
# Average Reward over the Evaluation Step: 1914.393475
# ---------------------------------------
# Total Timesteps: 861201 Episode Num: 2240 Reward: 1875.5113351099128
# Total Timesteps: 862201 Episode Num: 2241 Reward: 1947.0299212322316
# Total Timesteps: 863201 Episode Num: 2242 Reward: 1859.7683167405485
# Total Timesteps: 864201 Episode Num: 2243 Reward: 1876.5197899439636
# Total Timesteps: 864311 Episode Num: 2244 Reward: 189.18923708634316
# Total Timesteps: 865311 Episode Num: 2245 Reward: 1923.4848755578805
# ---------------------------------------
# Average Reward over the Evaluation Step: 1908.869479
# ---------------------------------------
# Total Timesteps: 866311 Episode Num: 2246 Reward: 1952.2420868815739
# Total Timesteps: 866832 Episode Num: 2247 Reward: 1034.119078250732
# Total Timesteps: 867087 Episode Num: 2248 Reward: 467.8656238461754
# Total Timesteps: 868087 Episode Num: 2249 Reward: 1967.6764959620966
# Total Timesteps: 868461 Episode Num: 2250 Reward: 689.4257903365296
# Total Timesteps: 869461 Episode Num: 2251 Reward: 1799.8548340160407
# Total Timesteps: 870461 Episode Num: 2252 Reward: 1876.775773557588
# ---------------------------------------
# Average Reward over the Evaluation Step: 1793.462189
# ---------------------------------------
# Total Timesteps: 871461 Episode Num: 2253 Reward: 1778.0632567837056
# Total Timesteps: 872461 Episode Num: 2254 Reward: 1956.3358674521774
# Total Timesteps: 873461 Episode Num: 2255 Reward: 1857.1793899512593
# Total Timesteps: 874461 Episode Num: 2256 Reward: 1899.78404246793
# Total Timesteps: 875461 Episode Num: 2257 Reward: 1854.1533764747512
# ---------------------------------------
# Average Reward over the Evaluation Step: 1896.835079
# ---------------------------------------
# Total Timesteps: 876461 Episode Num: 2258 Reward: 1896.8731151870284
# Total Timesteps: 877461 Episode Num: 2259 Reward: 1946.358392445409
# Total Timesteps: 878461 Episode Num: 2260 Reward: 1934.63718749376
# Total Timesteps: 879461 Episode Num: 2261 Reward: 1956.3747651919648
# Total Timesteps: 880461 Episode Num: 2262 Reward: 1906.398527652397
# ---------------------------------------
# Average Reward over the Evaluation Step: 1925.810494
# ---------------------------------------
# Total Timesteps: 881461 Episode Num: 2263 Reward: 1917.4907195209148
# Total Timesteps: 882461 Episode Num: 2264 Reward: 1920.051021298229
# Total Timesteps: 883461 Episode Num: 2265 Reward: 1891.7223910805317
# Total Timesteps: 884461 Episode Num: 2266 Reward: 1946.5191955298767
# Total Timesteps: 885461 Episode Num: 2267 Reward: 1886.6516916276194
# ---------------------------------------
# Average Reward over the Evaluation Step: 1967.179157
# ---------------------------------------
# Total Timesteps: 886461 Episode Num: 2268 Reward: 1937.3050856880334
# Total Timesteps: 887461 Episode Num: 2269 Reward: 1850.3584530992728
# Total Timesteps: 887907 Episode Num: 2270 Reward: 847.9698973793853
# Total Timesteps: 888907 Episode Num: 2271 Reward: 1925.618568653051
# Total Timesteps: 889907 Episode Num: 2272 Reward: 1953.7045928123848
# Total Timesteps: 890266 Episode Num: 2273 Reward: 699.4964861240305
# ---------------------------------------
# Average Reward over the Evaluation Step: 2025.373184
# ---------------------------------------
# Total Timesteps: 891266 Episode Num: 2274 Reward: 1997.669067825128
# Total Timesteps: 892266 Episode Num: 2275 Reward: 1976.3005087331676
# Total Timesteps: 893266 Episode Num: 2276 Reward: 1977.740222980792
# Total Timesteps: 894266 Episode Num: 2277 Reward: 1896.8416385907328
# Total Timesteps: 895266 Episode Num: 2278 Reward: 1845.8730695467518
# ---------------------------------------
# Average Reward over the Evaluation Step: 1994.153104
# ---------------------------------------
# Total Timesteps: 896266 Episode Num: 2279 Reward: 1991.4078661835506
# Total Timesteps: 897266 Episode Num: 2280 Reward: 1934.453805297421
# Total Timesteps: 898266 Episode Num: 2281 Reward: 1931.263754794503
# Total Timesteps: 899266 Episode Num: 2282 Reward: 1984.2329958279292
# Total Timesteps: 900266 Episode Num: 2283 Reward: 1924.2676000462213
# ---------------------------------------
# Average Reward over the Evaluation Step: 1976.313999
# ---------------------------------------
# Total Timesteps: 901266 Episode Num: 2284 Reward: 1968.6531810327215
# Total Timesteps: 902266 Episode Num: 2285 Reward: 1885.445809993538
# Total Timesteps: 903266 Episode Num: 2286 Reward: 1957.682523265252
# Total Timesteps: 904266 Episode Num: 2287 Reward: 1916.8173981189393
# Total Timesteps: 905266 Episode Num: 2288 Reward: 1961.1933579091606
# ---------------------------------------
# Average Reward over the Evaluation Step: 1945.702805
# ---------------------------------------
# Total Timesteps: 906266 Episode Num: 2289 Reward: 1946.1849280032409
# Total Timesteps: 907266 Episode Num: 2290 Reward: 1922.8823871517277
# Total Timesteps: 908266 Episode Num: 2291 Reward: 1931.1072853118735
# Total Timesteps: 909266 Episode Num: 2292 Reward: 1958.502143686302
# Total Timesteps: 910266 Episode Num: 2293 Reward: 1925.7236011122075
# ---------------------------------------
# Average Reward over the Evaluation Step: 1619.700076
# ---------------------------------------
# Total Timesteps: 911266 Episode Num: 2294 Reward: 1975.8368436295502
# Total Timesteps: 912266 Episode Num: 2295 Reward: 1967.6482738905383
# Total Timesteps: 913266 Episode Num: 2296 Reward: 2007.6470841488283
# Total Timesteps: 914266 Episode Num: 2297 Reward: 1957.8546140186195
# Total Timesteps: 914660 Episode Num: 2298 Reward: 748.739286288893
# Total Timesteps: 915660 Episode Num: 2299 Reward: 1988.0694744773
# ---------------------------------------
# Average Reward over the Evaluation Step: 1954.130816
# ---------------------------------------
# Total Timesteps: 916660 Episode Num: 2300 Reward: 1959.4522455179822
# Total Timesteps: 917660 Episode Num: 2301 Reward: 2015.670128759596
# Total Timesteps: 918660 Episode Num: 2302 Reward: 1903.788881300991
# Total Timesteps: 919660 Episode Num: 2303 Reward: 1934.1098663946423
# Total Timesteps: 920660 Episode Num: 2304 Reward: 1856.6793223636553
# ---------------------------------------
# Average Reward over the Evaluation Step: 2005.973038
# ---------------------------------------
# Total Timesteps: 921660 Episode Num: 2305 Reward: 1977.515459287705
# Total Timesteps: 922660 Episode Num: 2306 Reward: 1929.3846548498195
# Total Timesteps: 923375 Episode Num: 2307 Reward: 1370.8162617679181
# Total Timesteps: 923691 Episode Num: 2308 Reward: 571.4773719815246
# Total Timesteps: 924691 Episode Num: 2309 Reward: 1895.2677973996265
# Total Timesteps: 925691 Episode Num: 2310 Reward: 1829.7847533377026
# ---------------------------------------
# Average Reward over the Evaluation Step: 1922.107144
# ---------------------------------------
# Total Timesteps: 926691 Episode Num: 2311 Reward: 1901.226079568309
# Total Timesteps: 927691 Episode Num: 2312 Reward: 1926.638484918942
# Total Timesteps: 928691 Episode Num: 2313 Reward: 1975.2526687862958
# Total Timesteps: 929691 Episode Num: 2314 Reward: 1888.0355838802454
# Total Timesteps: 930691 Episode Num: 2315 Reward: 2013.168295063357
# ---------------------------------------
# Average Reward over the Evaluation Step: 1939.286590
# ---------------------------------------
# Total Timesteps: 931691 Episode Num: 2316 Reward: 1916.762358890432
# Total Timesteps: 932691 Episode Num: 2317 Reward: 1922.2660446559494
# Total Timesteps: 933691 Episode Num: 2318 Reward: 1908.384223084032
# Total Timesteps: 934691 Episode Num: 2319 Reward: 1871.449940413076
# Total Timesteps: 934762 Episode Num: 2320 Reward: 114.6068089142429
# Total Timesteps: 934890 Episode Num: 2321 Reward: 234.79342681283075
# Total Timesteps: 934964 Episode Num: 2322 Reward: 117.90008009933861
# Total Timesteps: 935964 Episode Num: 2323 Reward: 1968.0260502461379
# ---------------------------------------
# Average Reward over the Evaluation Step: 241.586652
# ---------------------------------------
# Total Timesteps: 936094 Episode Num: 2324 Reward: 230.43997303052274
# Total Timesteps: 936231 Episode Num: 2325 Reward: 251.18590679329762
# Total Timesteps: 936735 Episode Num: 2326 Reward: 1019.5759429925793
# Total Timesteps: 936876 Episode Num: 2327 Reward: 235.0492757379207
# Total Timesteps: 937014 Episode Num: 2328 Reward: 242.34567463209578
# Total Timesteps: 937159 Episode Num: 2329 Reward: 250.4806860656594
# Total Timesteps: 937293 Episode Num: 2330 Reward: 242.92562528828515
# Total Timesteps: 937487 Episode Num: 2331 Reward: 356.6340266781044
# Total Timesteps: 937617 Episode Num: 2332 Reward: 222.01894691678476
# Total Timesteps: 937816 Episode Num: 2333 Reward: 353.48165709762634
# Total Timesteps: 938207 Episode Num: 2334 Reward: 758.7138860416507
# Total Timesteps: 939207 Episode Num: 2335 Reward: 1872.7233497433324
# Total Timesteps: 940207 Episode Num: 2336 Reward: 1957.3119083532113
# ---------------------------------------
# Average Reward over the Evaluation Step: 1828.517255
# ---------------------------------------
# Total Timesteps: 941207 Episode Num: 2337 Reward: 1820.4153388762893
# Total Timesteps: 941424 Episode Num: 2338 Reward: 378.7805126463611
# Total Timesteps: 942424 Episode Num: 2339 Reward: 1939.9591239209378
# Total Timesteps: 943424 Episode Num: 2340 Reward: 1952.9473672682548
# Total Timesteps: 944424 Episode Num: 2341 Reward: 1977.83257536218
# Total Timesteps: 944819 Episode Num: 2342 Reward: 715.5372397028767
# Total Timesteps: 945819 Episode Num: 2343 Reward: 1959.357719425248
# ---------------------------------------
# Average Reward over the Evaluation Step: 1923.336380
# ---------------------------------------
# Total Timesteps: 946819 Episode Num: 2344 Reward: 1905.3725869942741
# Total Timesteps: 947819 Episode Num: 2345 Reward: 2007.7015482218828
# Total Timesteps: 948819 Episode Num: 2346 Reward: 2043.1456771827168
# Total Timesteps: 949819 Episode Num: 2347 Reward: 1991.8108776954853
# Total Timesteps: 950819 Episode Num: 2348 Reward: 1912.7652904025706
# ---------------------------------------
# Average Reward over the Evaluation Step: 2046.213419
# ---------------------------------------
# Total Timesteps: 951819 Episode Num: 2349 Reward: 2011.0959616864097
# Total Timesteps: 952819 Episode Num: 2350 Reward: 1928.3687621540973
# Total Timesteps: 953819 Episode Num: 2351 Reward: 1998.5310854211548
# Total Timesteps: 954819 Episode Num: 2352 Reward: 1921.4177774821678
# Total Timesteps: 955819 Episode Num: 2353 Reward: 1882.6636788656524
# ---------------------------------------
# Average Reward over the Evaluation Step: 1972.568704
# ---------------------------------------
# Total Timesteps: 956819 Episode Num: 2354 Reward: 1946.2930499166703
# Total Timesteps: 957819 Episode Num: 2355 Reward: 1902.200205113843
# Total Timesteps: 958819 Episode Num: 2356 Reward: 1938.3797484753763
# Total Timesteps: 959819 Episode Num: 2357 Reward: 1927.2156609474416
# Total Timesteps: 960819 Episode Num: 2358 Reward: 1967.7730492625813
# ---------------------------------------
# Average Reward over the Evaluation Step: 1932.634146
# ---------------------------------------
# Total Timesteps: 961819 Episode Num: 2359 Reward: 1940.9753176804338
# Total Timesteps: 962819 Episode Num: 2360 Reward: 1853.7717207469907
# Total Timesteps: 963819 Episode Num: 2361 Reward: 1774.0040735846544
# Total Timesteps: 964819 Episode Num: 2362 Reward: 1855.2314889641787
# Total Timesteps: 965819 Episode Num: 2363 Reward: 1946.0907166587156
# ---------------------------------------
# Average Reward over the Evaluation Step: 1862.089526
# ---------------------------------------
# Total Timesteps: 966819 Episode Num: 2364 Reward: 1801.9047062553861
# Total Timesteps: 967819 Episode Num: 2365 Reward: 1894.6763990903135
# Total Timesteps: 968819 Episode Num: 2366 Reward: 1835.5726341543677
# Total Timesteps: 969819 Episode Num: 2367 Reward: 2014.7163913165186
# Total Timesteps: 970819 Episode Num: 2368 Reward: 1959.9044505315308
# ---------------------------------------
# Average Reward over the Evaluation Step: 1918.503927
# ---------------------------------------
# Total Timesteps: 971819 Episode Num: 2369 Reward: 1915.0111435586275
# Total Timesteps: 972819 Episode Num: 2370 Reward: 1929.4150770793972
# Total Timesteps: 973819 Episode Num: 2371 Reward: 1946.0053399581047
# Total Timesteps: 974314 Episode Num: 2372 Reward: 959.7340030349093
# Total Timesteps: 974631 Episode Num: 2373 Reward: 568.133323959087
# Total Timesteps: 975142 Episode Num: 2374 Reward: 989.1331004363753
# ---------------------------------------
# Average Reward over the Evaluation Step: 1115.436056
# ---------------------------------------
# Total Timesteps: 975274 Episode Num: 2375 Reward: 215.53055014679143
# Total Timesteps: 976274 Episode Num: 2376 Reward: 1922.053453813605
# Total Timesteps: 977274 Episode Num: 2377 Reward: 1936.8831356028306
# Total Timesteps: 978274 Episode Num: 2378 Reward: 1890.222582478264
# Total Timesteps: 979274 Episode Num: 2379 Reward: 1951.6047078757972
# Total Timesteps: 980274 Episode Num: 2380 Reward: 1885.5624873062752
# ---------------------------------------
# Average Reward over the Evaluation Step: 1921.428969
# ---------------------------------------
# Total Timesteps: 981274 Episode Num: 2381 Reward: 1902.34414170602
# Total Timesteps: 982274 Episode Num: 2382 Reward: 1825.7529435191932
# Total Timesteps: 983274 Episode Num: 2383 Reward: 1938.8635233818952
# Total Timesteps: 984274 Episode Num: 2384 Reward: 1945.618314505238
# Total Timesteps: 985274 Episode Num: 2385 Reward: 1929.9603458932338
# ---------------------------------------
# Average Reward over the Evaluation Step: 1801.748863
# ---------------------------------------
# Total Timesteps: 986274 Episode Num: 2386 Reward: 1975.374766499144
# Total Timesteps: 987274 Episode Num: 2387 Reward: 1979.193173528661
# Total Timesteps: 988274 Episode Num: 2388 Reward: 1936.3059813158138
# Total Timesteps: 989274 Episode Num: 2389 Reward: 1912.7892858238977
# Total Timesteps: 990274 Episode Num: 2390 Reward: 2040.61403096974
# ---------------------------------------
# Average Reward over the Evaluation Step: 1992.088184
# ---------------------------------------
# Total Timesteps: 991274 Episode Num: 2391 Reward: 1959.6492040758267
# Total Timesteps: 992274 Episode Num: 2392 Reward: 1989.8006041395927
# Total Timesteps: 993274 Episode Num: 2393 Reward: 1951.9598458710266
# Total Timesteps: 993369 Episode Num: 2394 Reward: 163.9141811178085
# Total Timesteps: 993465 Episode Num: 2395 Reward: 167.6787612700141
# Total Timesteps: 994465 Episode Num: 2396 Reward: 1966.480463949466
# Total Timesteps: 994794 Episode Num: 2397 Reward: 609.3561470238084
# Total Timesteps: 994886 Episode Num: 2398 Reward: 158.83206537819194
# Total Timesteps: 994984 Episode Num: 2399 Reward: 164.6094292352372
# Total Timesteps: 995984 Episode Num: 2400 Reward: 1984.5789831858806
# ---------------------------------------
# Average Reward over the Evaluation Step: 1939.336693
# ---------------------------------------
# Total Timesteps: 996984 Episode Num: 2401 Reward: 1913.3227222143828
# Total Timesteps: 997984 Episode Num: 2402 Reward: 1977.1607801390828
# Total Timesteps: 998984 Episode Num: 2403 Reward: 1915.3841442555565
# Total Timesteps: 999984 Episode Num: 2404 Reward: 1827.5690344657555
# ---------------------------------------
# Average Reward over the Evaluation Step: 1789.303804
# ---------------------------------------

# %% [markdown]
# ## Inference

# %%
class Actor(nn.Module):
  
  def __init__(self, state_dim, action_dim, max_action):
    super(Actor, self).__init__()
    self.layer_1 = nn.Linear(state_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, action_dim)
    self.max_action = max_action

  def forward(self, x):
    x = F.relu(self.layer_1(x))
    x = F.relu(self.layer_2(x))
    x = self.max_action * torch.tanh(self.layer_3(x)) 
    return x

class Critic(nn.Module):
  
  def __init__(self, state_dim, action_dim):
    super(Critic, self).__init__()
    # Defining the first Critic neural network
    self.layer_1 = nn.Linear(state_dim + action_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, 1)
    # Defining the second Critic neural network
    self.layer_4 = nn.Linear(state_dim + action_dim, 400)
    self.layer_5 = nn.Linear(400, 300)
    self.layer_6 = nn.Linear(300, 1)

  def forward(self, x, u):
    xu = torch.cat([x, u], 1)
    # Forward-Propagation on the first Critic Neural Network
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    # Forward-Propagation on the second Critic Neural Network
    x2 = F.relu(self.layer_4(xu))
    x2 = F.relu(self.layer_5(x2))
    x2 = self.layer_6(x2)
    return x1, x2

  def Q1(self, x, u):
    xu = torch.cat([x, u], 1)
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    return x1

# Selecting the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Building the whole Training Process into a class

class TD3(object):
  
  def __init__(self, state_dim, action_dim, max_action):
    self.actor = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target.load_state_dict(self.actor.state_dict())
    self.actor_optimizer = torch.optim.Adam(self.actor.parameters())
    self.critic = Critic(state_dim, action_dim).to(device)
    self.critic_target = Critic(state_dim, action_dim).to(device)
    self.critic_target.load_state_dict(self.critic.state_dict())
    self.critic_optimizer = torch.optim.Adam(self.critic.parameters())
    self.max_action = max_action

  def select_action(self, state):
    state = torch.Tensor(state.reshape(1, -1)).to(device)
    return self.actor(state).cpu().data.numpy().flatten()

  def train(self, replay_buffer, iterations, batch_size=100, discount=0.99, tau=0.005, policy_noise=0.2, noise_clip=0.5, policy_freq=2):
    
    for it in range(iterations):
      
      # Step 4: We sample a batch of transitions (s, s’, a, r) from the memory
      batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = replay_buffer.sample(batch_size)
      state = torch.Tensor(batch_states).to(device)
      next_state = torch.Tensor(batch_next_states).to(device)
      action = torch.Tensor(batch_actions).to(device)
      reward = torch.Tensor(batch_rewards).to(device)
      done = torch.Tensor(batch_dones).to(device)
      
      # Step 5: From the next state s’, the Actor target plays the next action a’
      next_action = self.actor_target(next_state)
      
      # Step 6: We add Gaussian noise to this next action a’ and we clamp it in a range of values supported by the environment
      noise = torch.Tensor(batch_actions).data.normal_(0, policy_noise).to(device)
      noise = noise.clamp(-noise_clip, noise_clip)
      next_action = (next_action + noise).clamp(-self.max_action, self.max_action)
      
      # Step 7: The two Critic targets take each the couple (s’, a’) as input and return two Q-values Qt1(s’,a’) and Qt2(s’,a’) as outputs
      target_Q1, target_Q2 = self.critic_target(next_state, next_action)
      
      # Step 8: We keep the minimum of these two Q-values: min(Qt1, Qt2)
      target_Q = torch.min(target_Q1, target_Q2)
      
      # Step 9: We get the final target of the two Critic models, which is: Qt = r + γ * min(Qt1, Qt2), where γ is the discount factor
      target_Q = reward + ((1 - done) * discount * target_Q).detach()
      
      # Step 10: The two Critic models take each the couple (s, a) as input and return two Q-values Q1(s,a) and Q2(s,a) as outputs
      current_Q1, current_Q2 = self.critic(state, action)
      
      # Step 11: We compute the loss coming from the two Critic models: Critic Loss = MSE_Loss(Q1(s,a), Qt) + MSE_Loss(Q2(s,a), Qt)
      critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)
      
      # Step 12: We backpropagate this Critic loss and update the parameters of the two Critic models with a SGD optimizer
      self.critic_optimizer.zero_grad()
      critic_loss.backward()
      self.critic_optimizer.step()
      
      # Step 13: Once every two iterations, we update our Actor model by performing gradient ascent on the output of the first Critic model
      if it % policy_freq == 0:
        actor_loss = -self.critic.Q1(state, self.actor(state)).mean()
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()
        
        # Step 14: Still once every two iterations, we update the weights of the Actor target by polyak averaging
        for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
        
        # Step 15: Still once every two iterations, we update the weights of the Critic target by polyak averaging
        for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
  
  # Making a save method to save a trained model
  def save(self, filename, directory):
    torch.save(self.actor.state_dict(), '%s/%s_actor.pth' % (directory, filename))
    torch.save(self.critic.state_dict(), '%s/%s_critic.pth' % (directory, filename))
  
  # Making a load method to load a pre-trained model
  def load(self, filename, directory):
    self.actor.load_state_dict(torch.load('%s/%s_actor.pth' % (directory, filename)))
    self.critic.load_state_dict(torch.load('%s/%s_critic.pth' % (directory, filename)))

def evaluate_policy(policy, eval_episodes=10):
  avg_reward = 0.
  for _ in range(eval_episodes):
    obs = env.reset()
    done = False
    while not done:
      action = policy.select_action(np.array(obs))
      obs, reward, done, _ = env.step(action)
      avg_reward += reward
  avg_reward /= eval_episodes
  print ("---------------------------------------")
  print ("Average Reward over the Evaluation Step: %f" % (avg_reward))
  print ("---------------------------------------")
  return avg_reward

env_name = "Walker2DBulletEnv-v0"
seed = 0

file_name = "%s_%s_%s" % ("TD3", env_name, str(seed))
print ("---------------------------------------")
print ("Settings: %s" % (file_name))
print ("---------------------------------------")

eval_episodes = 10
save_env_vid = True
env = gym.make(env_name)
max_episode_steps = env._max_episode_steps
if save_env_vid:
  env = wrappers.Monitor(env, monitor_dir, force = True)
  env.reset()
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])
policy = TD3(state_dim, action_dim, max_action)
policy.load(file_name, './pytorch_models/')
_ = evaluate_policy(policy, eval_episodes=eval_episodes)
# Out:
# ---------------------------------------
# Settings: TD3_Walker2DBulletEnv-v0_0
# ---------------------------------------
# ---------------------------------------
# Average Reward over the Evaluation Step: 1787.820301
# ---------------------------------------
